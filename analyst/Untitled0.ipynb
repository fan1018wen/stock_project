# %%
import pymongo

# %%
Article = pymongo.Connection().stock.Article

# %%
import simhash

# %%
c=simhash.Simhash(s)

# %%
s=Article.find()

# %%
for i in Article.find().sort("title").limit(30):
    print i['title'],
    print simhash.Simhash(i['body']).value
# Out:
# (05/15)晚间沪深上市公司重大事项公告最新快递
# 15829868879757430256
# (05/15)晚间沪深上市公司重大事项公告最新快递
# 15829868879757430256
# (05/16)下周沪深上市公司重大事项公告最新快递
# 14460770280621203384
# (5/15)十大博文精粹：三连阴后将如何演变？
# 10217236815986031952
# *ST建摩B向深交所申请撤销退市风险警示 9972106333568207220
# *ST民和签战略合作协议 推广新产品“新壮态” 2931456892348245948
# 121家公司即将分红 逾1.3亿元追捧22只高送转股
# 14676943045555083760
# 121家公司将分红 亿元大单追捧22只高送转股
# 14676943045555085296
# 144亿资金净流出
# 14604885452588801844
# 144亿资金净流出
# 14604885452588801844
# 144亿资金净流出
# 14604885452588801844
# 15日人民币即期汇率开盘报6.2247 升42个基点 11600690729924004628
# 15日最具爆发力六大牛股(名单)
# 16352281573822548280
# 19日机构强推买入 6股极度低估 9506800710215359928
# 2000点保卫战留悬念
# 839611063056592888
# 2000点保卫战留悬念
# 839611063056592888
# 2000点保卫战留悬念
# 839611063056592888
# 2000点成关键支撑 政策底再经考验
# 14692688052062772600
# 2014年世界电信日大会在京举行 张峰出席会议 16915048248606542264
# 2020点附近震荡 等待周末消息面明朗
# 14620631421172936188
# 2020点附近震荡 等待周末消息面明朗
# 14620631421172936188
# 2020点附近震荡 等待周末消息面明朗
# 14620631421172936188
# 3D打印板概念股表现活跃 光韵达涨停 14674672555115338552
# 3个不明飞行物坠入黑龙江境内 现场已封锁(图) 186167677799740160
# 4月份统计局房地产数据点评
# 12299016063014918580
# 4月住户存款流失1.23万亿元：银行存款吸引力降低 14692676919767689588
# 4月居民消费价格水平同比涨1.8% 涨幅回落
# 9844807163328191446
# 4月规模以上港口货物吞吐量同比增5% 增速放缓 8691152085460913428
# 578只个股逆市吸金56亿元 军工等3行业酝酿新热点
# 14604885451381136184
# 578只个股逆市吸金56亿元 军工等3行业酝酿新热点
# 14604885451381136184

# %%
s=Article.find()

# %%
data = {
    1: u'How are you? I Am fine. blar blar blar blar blar Thanks.',
    2: u'How are you i am fine. blar blar blar blar blar than',
    3: u'This is simhash test.',
}
objs = [(str(k), simhash.Simhash(v)) for k, v in data.items()]

# %%
for i in objs: print i[1].value
# Out:
# 8440240427182201978
# 8440240356449459322
# 9984379969213434071

# %%
index = simhash.SimhashIndex(objs)

# %%
index.get_near_dups(s)
# Out:
# []

# %%
s=simhash.Simhash(u"This is simhash test.a")

# %%
for item in Article.find():
    body = item['body']
    sim = simhash.Simhash(body).value
    item['sim'] = str(sim)
    Article.save(item)

# %%
import jieba

# %%
s=Article.find_one()['body']

# %%
import jieba.analyse

# %%
for i in jieba.analyse.extract_tags(html2text(s)):print i
# Out:
# 衍生品
# 风险
# 指数
# 金融
# 回报
# 利率
# 管理
# 资产
# 期货
# 市场
# 财富
# 杠杆
# 易盛
# 期权
# 需要
# 交易
# 美国
# 政府
# 今天
# 概念

# %%
import lxml

# %%
def html2text(html): 
     tree = lxml.etree.fromstring(html, lxml.etree.HTMLParser())if  isinstance(html, basestring) else html 
     for skiptag in ('//script', '//iframe'): 
         for node in tree.xpath(skiptag): 
             node.getparent().remove(node) 
     return lxml.etree.tounicode(tree, method='text')

# %%
import lxml.etree

# %%
for item in Article.find():
    body = item['body']
    text = html2text(body)
    top = jieba.analyse.extract_tags(text)
    item['keyword'] = top
    Article.save(item)

# %%
all_keyword=[]
for item in Article.find():
    keyword = item['keyword']
    all_keyword+=keyword

# %%
from collections import Counter

# %%
cou = Counter(all_keyword)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-9f5322c8482d> in <module>()
# ----> 1 print json.dumps(sa)
#
# C:\Python27\lib\json\__init__.pyc in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     241         cls is None and indent is None and separators is None and
#     242         encoding == 'utf-8' and default is None and not sort_keys and not kw):
# --> 243         return _default_encoder.encode(obj)
#     244     if cls is None:
#     245         cls = JSONEncoder
#
# C:\Python27\lib\json\encoder.pyc in encode(self, o)
#     205         # exceptions aren't as detailed.  The list call should be roughly
#     206         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 207         chunks = self.iterencode(o, _one_shot=True)
#     208         if not isinstance(chunks, (list, tuple)):
#     209             chunks = list(chunks)
#
# C:\Python27\lib\json\encoder.pyc in iterencode(self, o, _one_shot)
#     268                 self.key_separator, self.item_separator, self.sort_keys,
#     269                 self.skipkeys, _one_shot)
# --> 270         return _iterencode(o, 0)
#     271
#     272 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# C:\Python27\lib\json\encoder.pyc in default(self, o)
#     182
#     183         """
# --> 184         raise TypeError(repr(o) + " is not JSON serializable")
#     185
#     186     def encode(self, o):
#
# TypeError: <simhash.Simhash object at 0x12EDE730> is not JSON serializable

# %%
for i in Article.find({"keyword":"跃然纸上"}) : print i['title'],i['url']
# Out:
# 耐心低吸三类股 http://stock.eastmoney.com/news/1412,20140515384479823.html
# 券商股杀跌 两市快速下挫深成指跌逾1% http://stock.eastmoney.com/news/1406,20140515384624873.html
# 耐心低吸三类股 http://stock.eastmoney.com/news/1406,20140515384479823.html
# 耐心低吸三类股 http://stock.eastmoney.com/news/1407,20140515384479823.html

# %%
os.getcwd()
# Out:
# 'Y:\\stock_project\\analyst'

# %%
sys.path.append("..")

# %%
s=__import__("../suippet.py")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-115-2d3933eb69e6> in <module>()
# ----> 1 s=__import__("../suippet.py")
#
# ImportError: Import by filename is not supported.

# %%
import snippet

# %%
snippet.html2text

# %%
s=u'''数据统计显示，近30日内16只银行股(申万一级行业分类)全部被机构看好，给予“增持”或“买入”投资评级。

　　值得一提的是，平安银行(行情 股吧 买卖点)近30日内有14家机构给予“买入”评级，7家给予“增持”评级。公司是全国性股份制商业银行，拥有38家分行，机构网点528家，在北京、香港设有代表处，并与境内外众多国家和地区逾2000家银行建立了代理行关系。公司确立了“面向中小企业，面向贸易融资”发展战略，独创的“线上供应链金融”在线服务平台，在互联网时代继续保持领先的服务优势。
  '''

sa= simhash.Simhash(s)

# %%
s=u'''数据统计显示，近30日内16只银行股(申万一级行业分类)全部被机构看好，给予“增持”或“买入”投资评级。

　　值得一提的是，平安dasdasdas银行(行情 股吧 买卖点)近30日内有14家机构给予“买入”评级，7家给予“增持”评级。公司是全国性股份制商业银行，拥有38家分行，机构网点528家，在北京、香港设有代表处，并与境内外众多国家和地区逾2000家银行建立了代理行关系。公司确立了“面向中小企业，面向贸易融资”发展战略，独创的“线上供应链金融”在线服务平台，在互联网时代继续保持领先的服务优势。
  '''

sb= simhash.Simhash(s)

# %%
sa.distance(sb)
# Out:
# 10

# %%
sa.value=12677085740760190516L

# %%
sa.distance(sb)
# Out:
# 13

# %%
sc=simhash.Simhash()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-169-a37764e5d76d> in <module>()
# ----> 1 sc=simhash.Simhash()
#
# TypeError: __init__() takes at least 2 arguments (1 given)

# %%
c=12677085740760190516L

# %%
bin(7721317932675755796L)
# Out:
# '0b110101100100111101000011100000000011110111111011110111100010100'

# %%
bu = simhash.SimhashIndex({},k=50)
for i in Article.find({},{"title":1,"sim":1}).limit(1000):
    obj_id = i['title']
    hash_int = simhash.Simhash(int(i['sim']))
#     print hash_int.value?
    bu.add( obj_id,hash_int)

# %%
s=u'''
　近日发布的今年第一季度“星展人民币动力指数”显示，指数由上一季度的58.5下跌至57.6，主要是因为人民币汇率调整以及人民币在岸和离岸利差缩小，导致香港企业对人民币的需求及使用量较上一季度有所減少，但大型企业仍热衷于把握离岸人民币市场。

　　星展的调查访问结果显示，使用人民币产品的公司的比例在去年的第三季及第四季均达到高位，分别为38%和34%，但到了2014年第一季则跌至25%。另外，在2014年第一季度，只有24%的受访企业表示目前正使用或将在未来12个月考虑使用人民币付款和应收账款服务，而上一季度该比例为37%。

　　尽管香港企业对人民币的使用量减少，但大型企业仍然热衷把握离岸人民币市场。所有受访的大型企业表示，在过去12个月曾接受人民币客户订单/发票及贸易结算，以及有13%表示预计在未来12个月将进一步增加使用人民币。

　　星展银行(行情 专区)香港分行董事总经理郑思祯表示，由于目前市场缺乏离岸人民币投资选择，将继续推动人民币债券的殷切需求，2014年离岸人民币债券可望维持强势，因在岸流动资金依然不足，加上今年预期有大量的点心债券到期再融资。

　　值得注意的是，在2014年第一季有越来越多的企业开始使用更广泛、复杂的人民币产品。尽管在2013年第三季只有0.5%的企业使用人民币有期贷款，但在2014年第一季，使用率大幅上升至6%。另外，没有公司在2013年第三季及2013年第四季起计的过去12个月内投资任何人民币计价的股票，但有3%表示在2014年第一季持有上述投资。对此，星展银行 (香港) 经济研究部副总裁及经济师周洪礼表示，如果市场致力发展人民币产品和相关金融结构性产品，将有助提高企业对产品的需求。

　　据介绍，“星展人民币动力指数”追踪香港公司使用和接受人民币的实际情况，以及企业对未来采纳人民币的观点。相关调查按季度进行，2014年第一季度的调查工作是以电话访问的形式进行，共访问200多家香港公司的企业雇主和决策者。
'''

hash_int = simhash.Simhash(s)
print hash_int.value
# hash_int.value=16984474708400660144
print hash_int.distance( simhash.Simhash(16984474708400660144))
bu.k=20
r=bu.get_near_dups(hash_int)
pr(r)
# Out:
# WARNING:root:Big bucket found. key:0:0, len(ret):559
# WARNING:root:Big bucket found. key:1:a, len(ret):373
# 18415352786881533600
# 11
# set([u'8ba6e0d2eaf369b4,\u673a\u68b0\u677f\u5757\u5c0f\u5e45\u4e0b\u8dcc0.33%  \u5e38\u6797\u80a1\u4efd\u9006\u52bf\u4e0a\u6da8', u'8a86fbc01a634dd4,\u552f\u54c1\u4f1a\u4e1a\u7ee9\u4e5f\u75af\u72c2 \u5f53\u5f53\u7f51\u6253\u7834\u4e8f\u635f\u9b54\u5492', u'baa4f5c02afb51b2,\u62db\u5546\u8bc1\u5238\uff1a\u6e2f\u80a1\u5927\u5e02\u6216\u521b\u65b0\u4f4e\u540e\u7b51\u5e95', u'cbaef9f02af35ff0,121\u5bb6\u516c\u53f8\u5c06\u5206\u7ea2 \u4ebf\u5143\u5927\u5355\u8ffd\u636722\u53ea\u9ad8\u9001\u8f6c\u80a1', u'c8aee8f066f56570,\u5168\u7403\u98df\u7cd6\u5e93\u5b58\u62d0\u70b9\u6216\u73b0 \u7cd6\u4e1a\u80a1\u8fce\u5e03\u5c40\u826f\u673a(\u9644\u80a1)', u'4ae6e0540af1dfb4,\u6269\u5bb9\u538b\u529b\u96c6\u4e2d\u6765\u88ad \u6caa\u6df1\u80a1\u6307\u53cc\u53cc\u4e0b\u632b', u'a0fdeec17a498b14,15\u65e5\u4eba\u6c11\u5e01\u5373\u671f\u6c47\u7387\u5f00\u76d8\u62a56.2247 \u534742\u4e2a\u57fa\u70b9', u'4b26a1f00effcf14,\u8bc1\u76d1\u4f1a\uff1a\u653e\u5bbd\u5238\u5546\u51c6\u5165 \u5b9e\u65bd\u724c\u7167\u7ba1\u7406', u'cbe6a9d0d8e34ff4,\u5c71\u4e1c\u4e0a\u5e02\u516c\u53f8\u518d\u6dfb\u65b0\u519b \u5c71\u4e1c\u9f99\u5927\u4eca\u65e5\u901a\u8fc7\u53d1\u5ba1\u4f1a\u5ba1\u6838', u'c9afced03aeb6d70,\u66dd\u5b8b\u536b\u5e73\u9000\u51fa\u7eff\u57ce\u4e2d\u56fd \u9a6c\u4e91\u4e2a\u4eba\u8eab\u4efd\u6536\u8d2d\u7403\u961f', u'88a2fdf022f3df38,5\u670815\u65e5\u5348\u95f4\u6df1\u5e02\u516c\u544a\u6c47\u603b', u'802ff5c27853a594,\u5c71\u897f\u5c06\u4e8e\u8fd1\u671f\u51fa\u53f0\u7164\u70ad\u6551\u5e02\u201c17\u6761\u201d\u65b0\u653f', u'c8a6f1c032d25f3c,\u5468\u7d2f\u79ef\u6362\u624b\u7387\u524d\u4e8c\u5341\u53ea\u4e2a\u80a1\u5e02\u573a\u8868\u73b0(\u622a\u6b625.14)', u'caaee9d072f1df30,\u901a\u5a01\u80a1\u4efd\u653e\u91cf\u98d9\u5347 \u7845\u8c37\u5929\u5802\u8fd13\u4ebf\u5143\u5165\u80a1', u'2bcf9d27adb8634,\u7f8e\u4e09\u5927\u80a1\u6307\u6628\u65e5\u5168\u7ebf\u56de\u843d', u'c82291c232fb5f3e,\u534a\u65e5\u4e3b\u529b\u8d44\u91d1\u51c0\u6d41\u51fa\u524d\u5341\u4e2a\u80a1(5/16)', u'ba6cec4b8e9ad90,\u518d\u6b21\u6d4b\u8bd52000\u70b9\u652f\u6491', u'a2aced982a93a2b4,\u80fd\u6e90\u677f\u5757\u9886\u6da8\u7f8e\u80a1 \u4e2d\u67a2\u795e\u7ecf\u6216\u72ec\u9886\u98ce\u9a9a', u'19d5f59075b937bc,\u5217\u4e3e\u6563\u6237\u7092\u80a1\u768450\u6761\u6bdb\u75c5', u'8aade4d1e2f58710,\u6d66\u4e1c\u91d1\u6865\u5b9a\u589e\u4e0d\u8d852.92\u4ebf\u80a1 \u52df\u8d4430\u4ebf\u5143', u'43d526d4bae9a010,\u5229\u597d\u6570\u636e\u538b\u5236\u907f\u9669\u9700\u6c42 \u91d1\u4ef7\u5468\u56db\u8dcc0.9%', u'caae9d742ad66db4,\u4e2d\u5c0f\u677f\u6d3b\u8dc3\u80a1\u516c\u5f00\u4fe1\u606f(05/15)', u'81e5e5e01ed95334,\u6b27\u94f6\u964d\u606f\u9884\u671f\u63a8\u5347\u5168\u7403\u503a\u5e02 \u7f8e\u503a\u5347\u81f3\u534a\u5e74\u9ad8\u4f4d', u'caaed8e02a53df38,\u7279\u9ad8\u538b\u7834\u51b02000\u4ebf\u5e02\u573a\u6398\u91d1 5\u80a1\u9955\u992e\u76db\u5bb4', u'a2b5e5001afbbd3a,\u9694\u591c\u5168\u7403\u5e02\u573a\u7eb5\u89c8\uff1a\u9053\u6307\u6536\u8dcc1% \u954d\u4ef7\u5927\u8dcc6.4%', u'8ae6ede07af759b4,\u623f\u5730\u4ea7\u884c\u4e1a\uff1a\u4ece\u91cf\u53d8\u5230\u8d28\u53d8', u'cbaef9f06af74db0,\u5468\u4e00\u5c55\u671b\uff1a\u91cd\u70b9\u5e03\u5c40\u5341\u5927\u677f\u5757\u4f18\u8d28\u80a1', u'aba4a5d002ffd994,\u6caa\u6df1\u4e24\u5e02\u5468\u56db\u4f4e\u5f00 \u5e02\u573a\u8d70\u5f3a\u6216\u5f85\u6301\u7eed\u6027\u70ed\u70b9\u51fa\u73b0', u'caa6f9f02ad35f70,5\u5927\u5238\u5546\u5468\u4e94\u770b\u597d6\u677f\u575740\u80a1', u'caaee9e22ad359b8,\u521b\u65b0\u5927\u4f1a\u4eca\u53ec\u5f00 \u5238\u5546\u80a1\u53d7\u878d\u8d44\u8d44\u91d1\u6301\u7eed\u5173\u6ce8', u'caaef9f022d7db38,578\u53ea\u4e2a\u80a1\u9006\u5e02\u5438\u91d156\u4ebf\u5143 \u519b\u5de5\u7b493\u884c\u4e1a\u915d\u917f\u65b0\u70ed\u70b9', u'28aea08316c9a7bc,*ST\u6c11\u548c\u7b7e\u6218\u7565\u5408\u4f5c\u534f\u8bae \u63a8\u5e7f\u65b0\u4ea7\u54c1\u201c\u65b0\u58ee\u6001\u201d', u'c8a6b5c032d25f7c,\u6210\u4ea4\u91cf\u7a81\u589e\u524d\u5341\u53ea\u4e2a\u80a1 (\u622a\u6b625.14)', u'c8e2f16032d25f3c,\u65e9\u76d8\u6e38\u8d44\u5927\u5355\u629b\u552 ...
# set([])
# set([])
# set([])
# set([])
# set([])
# set([])
# set([])
# set([])
# set([])
# set([u'8ba6cac2aae18711,\u5ddd\u6295\u80fd\u6e90\uff1a\u9884\u8ba1\u96c5\u783b\u6c5f\u6c34\u7535\u4eca\u5e74\u5229\u6da6\u5c06\u8fbe40\u4ebf', u'a1bf63d090f9df75,\u5e7f\u897f\u6d77\u4e0a\u4e1d\u7ef8\u4e4b\u8def\u91cd\u70b9\u63a8\u8fdb8\u5927\u4ea7\u4e1a\u5408\u4f5c', u'cbaef9f02af35ff0,121\u5bb6\u516c\u53f8\u5c06\u5206\u7ea2 \u4ebf\u5143\u5927\u5355\u8ffd\u636722\u53ea\u9ad8\u9001\u8f6c\u80a1', u'c8aee8f066f56570,\u5168\u7403\u98df\u7cd6\u5e93\u5b58\u62d0\u70b9\u6216\u73b0 \u7cd6\u4e1a\u80a1\u8fce\u5e03\u5c40\u826f\u673a(\u9644\u80a1)', u'4ae6e0540af1dfb4,\u6269\u5bb9\u538b\u529b\u96c6\u4e2d\u6765\u88ad \u6caa\u6df1\u80a1\u6307\u53cc\u53cc\u4e0b\u632b', u'4b26a1f00effcf14,\u8bc1\u76d1\u4f1a\uff1a\u653e\u5bbd\u5238\u5546\u51c6\u5165 \u5b9e\u65bd\u724c\u7167\u7ba1\u7406', u'cbe6a9d0d8e34ff4,\u5c71\u4e1c\u4e0a\u5e02\u516c\u53f8\u518d\u6dfb\u65b0\u519b \u5c71\u4e1c\u9f99\u5927\u4eca\u65e5\u901a\u8fc7\u53d1\u5ba1\u4f1a\u5ba1\u6838', u'c9afced03aeb6d70,\u66dd\u5b8b\u536b\u5e73\u9000\u51fa\u7eff\u57ce\u4e2d\u56fd \u9a6c\u4e91\u4e2a\u4eba\u8eab\u4efd\u6536\u8d2d\u7403\u961f', u'802ff5c27853a594,\u5c71\u897f\u5c06\u4e8e\u8fd1\u671f\u51fa\u53f0\u7164\u70ad\u6551\u5e02\u201c17\u6761\u201d\u65b0\u653f', u'c8a6f1c032d25f3c,\u5468\u7d2f\u79ef\u6362\u624b\u7387\u524d\u4e8c\u5341\u53ea\u4e2a\u80a1\u5e02\u573a\u8868\u73b0(\u622a\u6b625.14)', u'caaee9d072f1df30,\u901a\u5a01\u80a1\u4efd\u653e\u91cf\u98d9\u5347 \u7845\u8c37\u5929\u5802\u8fd13\u4ebf\u5143\u5165\u80a1', u'2bcf9d27adb8634,\u7f8e\u4e09\u5927\u80a1\u6307\u6628\u65e5\u5168\u7ebf\u56de\u843d', u'8a86fbc01a634dd4,\u552f\u54c1\u4f1a\u4e1a\u7ee9\u4e5f\u75af\u72c2 \u5f53\u5f53\u7f51\u6253\u7834\u4e8f\u635f\u9b54\u5492', u'c82291c232fb5f3e,\u534a\u65e5\u4e3b\u529b\u8d44\u91d1\u51c0\u6d41\u51fa\u524d\u5341\u4e2a\u80a1(5/16)', u'ba6cec4b8e9ad90,\u518d\u6b21\u6d4b\u8bd52000\u70b9\u652f\u6491', u'19d5f59075b937bc,\u5217\u4e3e\u6563\u6237\u7092\u80a1\u768450\u6761\u6bdb\u75c5', u'8aade4d1e2f58710,\u6d66\u4e1c\u91d1\u6865\u5b9a\u589e\u4e0d\u8d852.92\u4ebf\u80a1 \u52df\u8d4430\u4ebf\u5143', u'caae9d742ad66db4,\u4e2d\u5c0f\u677f\u6d3b\u8dc3\u80a1\u516c\u5f00\u4fe1\u606f(05/15)', u'caaed8e02a53df38,\u7279\u9ad8\u538b\u7834\u51b02000\u4ebf\u5e02\u573a\u6398\u91d1 5\u80a1\u9955\u992e\u76db\u5bb4', u'cbaef9f06af74db0,\u5468\u4e00\u5c55\u671b\uff1a\u91cd\u70b9\u5e03\u5c40\u5341\u5927\u677f\u5757\u4f18\u8d28\u80a1', u'caa6f9f02ad35f70,5\u5927\u5238\u5546\u5468\u4e94\u770b\u597d6\u677f\u575740\u80a1', u'c8e2f16032d25f3c,\u65e9\u76d8\u6e38\u8d44\u5927\u5355\u629b\u552e\u7684\u524d30\u53ea\u4e2a\u80a1(5/15)', u'c8a2f1e032d25d7c,\u4eca\u65e5\u4e24\u5e02\u6e38\u8d44\u91cd\u70b9\u5173\u6ce8\u768430\u53ea\u4e2a\u80a1(5/15)', u'8ba6e8d3eaf9c510,5\u670815\u65e5\u5f02\u52a8\u80a1\u70b9\u8bc4 \u76d8\u70b9\u56db\u725b\u4e0e\u56db\u718a', u'3b56cc2a8f9a511,\u8010\u5fc3\u4f4e\u5438\u4e09\u7c7b\u80a1', u'c8eee9504a5b4eb4,\u56fd\u52a1\u9662\u9ad8\u5ea6\u91cd\u89c6\u98df\u54c1\u5b89\u5168 \u98df\u54c1\u5b89\u5168\u6982\u5ff5\u80a1\u6709\u671b\u7206\u53d1', u'c0ee2df33266dff9,\u56db\u65b9\u8fbe\u53d6\u5f972\u9879\u4e13\u52291\u9879\u8f6f\u4ef6\u8457\u4f5c\u6743', u'68eee35582f95574,\u53cd\u5f39\u592d\u6298 \u653f\u7b56\u5e95\u540e\u8fd8\u6709\u5e02\u573a\u5e95', u'53a6e4c022f5c598,\u654f\u611f\u7a97\u53e3\u5404\u8def\u5229\u7a7a\u9f50\u81f3 \u653f\u7b56\u5e95\u4e0d\u53ef\u4fe1', u'8b8d40526a6175b5,\u5c0f\u989d\u8d37\u6b3e\u516c\u53f8\u7ba1\u7406\u529e\u6cd5\u5f81\u6c42\u610f\u89c1 \u62df\u62d3\u5bbd\u7ecf\u8425\u8303\u56f4', u'4ab642d68ae1a495,\u4e2d\u56fd\u79fb\u52a8\u5ba3\u5e03\u5927\u5e45\u4e0b\u8c034G\u8d44\u8d39 \u6b66\u6c49\u51e1\u8c37\u6da8\u505c', u'abc1d5982a4537b6,\u4eba\u6c11\u5e01\u5bf9\u7f8e\u5143\u4e2d\u95f4\u4ef7\u53cd\u5f3913\u4e2a\u57fa\u70b9 \u62a56.1640', u'c8aeb16432d25fbc,\u6210\u4ea4\u91cf\u7a81\u589e\u524d\u5341\u53ea\u4e2a\u80a1 (\u622a\u6b625.15)', u'6b76e0d256fbdeb7,A\u80a1\u5982\u52a0\u5165MSCI \u56db\u7c7b\u80a1\u5c06\u53d7\u76ca', u'8aaed5fa2ae75df4,\u4e24\u5e02\u4f4e\u8ff7\u6743\u91cd\u80a1\u4 ...
# set([])
# set([])
# set([])
# set([])
# set([])
# set([u'caa6c16032d25d3c,\u8fde\u7eed\u4e0a\u6da8\u524d\u5341\u53ea\u4e2a\u80a1 (\u622a\u6b625.15)', u'bc73b2c2b2da5738,\u4e09\u677f\u80a1\u7968\u884c\u60c5\u52a8\u6001(5/15)\uff08\u4e8c\uff09', u'c0a3a372aef297f4,\u82cf\u4ea4\u79d1\u53d1\u884c\u80a1\u4efd\u8d2d\u4e70\u8d44\u4ea7\u7533\u8bf7\u83b7\u53d7\u7406', u'caa6d9706af0533c,\u8239\u8236\u677f\u5757\u6574\u4f53\u4e0a\u6da8\u8fd13% \u4e2d\u56fd\u8239\u8236\u9886\u6da8', u'ebac0cf13ad25b9c,\u6d77\u7fd4\u836f\u4e1a\u4e0b\u5348\u4e3e\u884c\u6295\u8d44\u8005\u89c1\u9762\u4f1a', u'c8aef16032d05f3c,\u5468\u7d2f\u79ef\u6362\u624b\u7387\u524d\u4e8c\u5341\u53ea\u4e2a\u80a1\u5e02\u573a\u8868\u73b0(\u622a\u6b625.15)', u'40ba4064a446113c,C919\u524d\u673a\u8eab\u5927\u90e8\u6bb515\u65e5\u5728\u4e2d\u822a\u5de5\u4e1a\u6d2a\u90fd\u6210\u529f\u4e0b\u7ebf', u'c8a6e1e032d25d7c,\u65e9\u76d8\u6e38\u8d44\u5927\u5355\u62a2\u7b79\u7684\u524d30\u53ea\u4e2a\u80a1(5/15)', u'd9aa9bf12ed64dbc,\u6caa\u5e02\u6d3b\u8dc3\u80a1\u516c\u5f00\u4fe1\u606f(A\u80a1)(05/15)', u'c8a6f1c032d25f3c,\u5468\u7d2f\u79ef\u6362\u624b\u7387\u524d\u4e8c\u5341\u53ea\u4e2a\u80a1\u5e02\u573a\u8868\u73b0(\u622a\u6b625.14)', u'c8a6b1c432d25d38,\u9ad8\u9001\u8f6c\u80a1\u884c\u60c5\u5347\u6e29 \u626c\u6770\u79d1\u62805\u6708\u6da8\u5e45\u8d8525%', u'd8a6b1e032d25d74,\u65e9\u76d8\u6e38\u8d44\u5927\u5355\u62a2\u7b79\u7684\u524d30\u53ea\u4e2a\u80a1', u'a9a6edf072d21f1c,\u4e92\u8054\u7f51\u5de8\u5934\u5de8\u8d44\u5e03\u5c40 \u8f66\u8054\u7f51\u6982\u5ff5\u80a1\u7206\u53d1', u'e9e04c9402aabb5c,\u4e16\u5609\u79d1\u6280\u6570\u636e\u6e90\u4e8e8\u5e74\u524d \u5927\u5ba2\u6237\u8fde\u5e74\u4e8f\u635f\u81ea\u8eab\u96be\u4fdd', u'd8a2f1e032d25d3c,\u4eca\u65e5\u573a\u5185\u6563\u6237\u8d44\u91d1\u91cd\u70b9\u5173\u6ce8\u768430\u53ea\u4e2a\u80a1\uff085/15\uff09', u'caa6f9f02ad07bf8,\u667a\u80fd\u7a7f\u6234\u677f\u5757\u4e2a\u80a1\u96c6\u4f53\u4e0b\u632b \u4e5d\u5b89\u533b\u7597\u4e0b\u8dcc\u903e7%', u'c8a681c232d25d3c,\u4e0b\u546825\u4ebf\u9650\u552e\u80a1\u89e3\u7981 8\u516c\u53f8\u5c06\u5b9e\u73b0\u5168\u6d41\u901a', u'cba6e8f06ad2db38,3D\u6253\u5370\u677f\u6982\u5ff5\u80a1\u8868\u73b0\u6d3b\u8dc3 \u5149\u97f5\u8fbe\u6da8\u505c', u'c8aeb16432d25fbc,\u6210\u4ea4\u91cf\u7a81\u589e\u524d\u5341\u53ea\u4e2a\u80a1 (\u622a\u6b625.15)', u'ab9198c01cdc4172,\u524d\u6d77\u5165\u533a\u4f01\u4e1a\u5df2\u8fbe6500\u5bb6', u'c9aafde02af05fbc,\u519c\u6797\u7267\u6e14\u677f\u5757\u8868\u73b0\u5f3a\u52bf \u9686\u5e73\u9ad8\u79d1\u5927\u6da8\u903e7%', u'caae9d742ad66db4,\u4e2d\u5c0f\u677f\u6d3b\u8dc3\u80a1\u516c\u5f00\u4fe1\u606f(05/15)', u'a15525c230d60c34,\u5348\u540e\u5f00\u76d8\uff1a\u4e24\u5e02\u80a1\u6307\u9707\u8361\u8d70\u4f4e \u6b21\u65b0\u80a1\u6d3b\u8dc3', u'c8aed16032d25d3c,\u8fde\u7eed\u4e0a\u6da8\u524d\u5341\u53ea\u4e2a\u80a1 (\u622a\u6b625.14)', u'c9a6e9f02ad2dbbc,\u6b21\u65b0\u80a1\u76d8\u4e2d\u6301\u7eed\u53d1\u529b \u6c47\u91d1\u80a1\u4efd\u8fde\u7eed\u4e09\u6da8\u505c', u'd8a6f1e032d25f7c,\u65e9\u76d8\u6e38\u8d44\u5927\u5355\u629b\u552e\u7684\u524d30\u53ea\u4e2a\u80a1', u'8aaee9c462f65fb0,\u6843\u82b1\u6c5f\u6709\u671b\u6210\u4e3a\u9996\u4e2a\u5f00\u5efa\u5185\u9646\u6838\u7535\u7ad9 5\u80a1\u6216\u7206\u53d1', u'c9a6f9702ad2ddbc,\u5238\u5546\u80a1\u5168\u7ebf\u98d8\u7eff \u56fd\u5143\u8bc1\u5238\u9886\u8dcc', u'cbaefdf02ad2cfb8,\u6cb3\u5317\u672c\u5730\u80a1\u5d1b\u8d77 \u5eca\u574a\u53d1\u5c55\u4e0a\u6da8\u903e7%', u'c8a6c14032d25f3c,\u6301\u7eed\u7f29\u91cf\u524d\u5341\u53ea\u4e2a\u80a1\u5e02\u573a\u8868\u73b0(\u622a\u6b625.14)', u'c8a6f1e032d25d3c,\u673a\u6784\u9996\u6b21\u5173\u6ce823\u80a1 \u6700\u5927\u6da8\u5e45\u8d8550%', u'61d408d0ba80897f,\u97e9\u56fd\u80a1\u5e02\u5fae\u8dcc0.03% \u7ec8\u6b62\u8fde\u7eed\u4e94\u65e5\u6da8\u52bf', u'c8a2d16232f25f3c,\u4e24\u5e02\u4f4e\u5e02\u76c8\u7387\u524d\u4e8c\u5341\u53ea\u4e2a\u80a1\u5e02\u573a\u8868\u73b0(\u622a\u6b625.15)', u'c8a6f1e032d25f3c,\u6301\u7eed\u653e\u91cf\u524d\u5341\u53ea\u4e2a\u80a1\u5e02\u573a\u8868\u73b0(\u622a\u6b625.15)', u'c8a6b1e032d25d7c,\u65e9\u76d8\u8d85\u7ea7\u8d44\u91 ...
# set([])
# set([])
# set([])
# set([])
# [
#   "智慧城市论坛倒计时 15股面临重大机遇",
#   "一季度港企对人民币需求及使用环比减少",
#   "8只股票莫名跳水 自然人股东挺扎眼"
# ]

# %%
hash_int.distance( simhash.Simhash(16984474708400660144))
# Out:
# 11

# %%
reload(simhash)
# Out:
# <module 'simhash' from 'C:\Python27\lib\site-packages\simhash\__init__.py'>
